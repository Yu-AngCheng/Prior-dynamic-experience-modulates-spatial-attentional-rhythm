# %%
# %matplotlib inline

import numpy as np
from scipy.io import loadmat, savemat

from fooof import FOOOF

# %%
# Load the mat file 
data = loadmat('PSD.mat')

# Unpack data from dictioanry, and squeeze numpy arrays
freqs = np.squeeze(data['f'])
psd = np.squeeze(np.mean(data['PSD_pretest'],axis=1))

# %%
i = 14
# Initialize FOOOF object
fm = FOOOF()
# Fit the FOOOF model, and report
fm.report(freqs, psd, [0.5, 10])
# Out:
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.47 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 0 - 10 Hz
#                                  Frequency Resolution is 0.47 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                          -3.4917, 0.1029
#
#                                        3 peaks were found:
#                                 CF:   1.63, PW:  0.323, BW:  0.50
#                                 CF:   2.79, PW:  0.453, BW:  1.23
#                                 CF:   5.06, PW:  0.248, BW:  2.46
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9368
#                                     Error of the fit is 0.0430
#
# ==================================================================================================
